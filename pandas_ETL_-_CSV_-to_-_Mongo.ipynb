# %%
# !pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymongo in c:\users\admin\appdata\roaming\python\python39\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from pymongo) (2.3.0)

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5013-AEF8
#
#  Directory of C:\Users\Admin\Desktop
#
# 30-03-2023  11:06    <DIR>          .
# 30-03-2023  11:06    <DIR>          ..
# 30-03-2023  11:06    <DIR>          .ipynb_checkpoints
# 30-03-2023  09:32             3,319 book.ipynb
# 29-03-2023  12:38    <DIR>          db
# 29-03-2023  12:57         3,192,561 diamonds.csv
# 21-03-2023  09:29                19 dummy.txt
# 30-03-2023  10:33           393,216 etldata.db
# 30-03-2023  11:03    <DIR>          files
# 30-03-2023  09:27            38,696 loans-raw.csv
# 29-03-2023  11:39    <DIR>          mongo
# 30-03-2023  10:42         3,973,120 mydatabase.db
# 30-03-2023  10:03            20,643 pandas2_-_ETL.ipynb
# 30-03-2023  11:06             5,983 pandas_ETL_-_CSV_-to_-_Mongo.ipynb
# 30-03-2023  11:04            24,577 pandas_ETL_CSV-to-RDBMS.ipynb
# 30-03-2023  11:03            10,861 pandas_ETL_RDBMS-to-CSV.ipynb
# 30-03-2023  11:04            16,224 pandas_ETL_RDBMS_to_csv.ipynb
# 29-03-2023  09:58    <DIR>          ping
# 28-03-2023  12:29    <DIR>          python
# 30-03-2023  10:44           280,302 VVS2.csv
#               12 File(s)      7,959,521 bytes
#                8 Dir(s)  481,090,207,744 bytes free

# %%
import pandas as pd

# %%
from pymongo import MongoClient

# %%
df=pd.read_csv("diamonds.csv")

# %%
client = MongoClient()

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.etl
coll = db.diamonds

# %%
df
# Out:
#            s  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# 4      2.75
# ...     ...
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64
#
# [53940 rows x 11 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#        index      s  carat        cut color clarity  depth  table  price  \
# 0          0      1   0.23      Ideal     E     SI2   61.5   55.0    326
# 1          1      2   0.21    Premium     E     SI1   59.8   61.0    326
# 2          2      3   0.23       Good     E     VS1   56.9   65.0    327
# 3          3      4   0.29    Premium     I     VS2   62.4   58.0    334
# 4          4      5   0.31       Good     J     SI2   63.3   58.0    335
# ...      ...    ...    ...        ...   ...     ...    ...    ...    ...
# 53935  53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936  53936  53937   0.72       Good     D     SI1   63.1   55.0   2757
# 53937  53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938  53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939  53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757
#
#           x     y     z
# 0      3.95  3.98  2.43
# 1      3.89  3.84  2.31
# 2      4.05  4.07  2.31
# 3      4.20  4.23  2.63
# 4      4.34  4.35  2.75
# ...     ...   ...   ...
# 53935  5.75  5.76  3.50
# 53936  5.69  5.75  3.61
# 53937  5.66  5.68  3.56
# 53938  6.15  6.12  3.74
# 53939  5.83  5.87  3.64
#
# [53940 rows x 12 columns]

# %%
data = df.to_dict("records")

# %%
data
# Out:
# [{'index': 0,
#   's': 1,
#   'carat': 0.23,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI2',
#   'depth': 61.5,
#   'table': 55.0,
#   'price': 326,
#   'x': 3.95,
#   'y': 3.98,
#   'z': 2.43},
#  {'index': 1,
#   's': 2,
#   'carat': 0.21,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 59.8,
#   'table': 61.0,
#   'price': 326,
#   'x': 3.89,
#   'y': 3.84,
#   'z': 2.31},
#  {'index': 2,
#   's': 3,
#   'carat': 0.23,
#   'cut': 'Good',
#   'color': 'E',
#   'clarity': 'VS1',
#   'depth': 56.9,
#   'table': 65.0,
#   'price': 327,
#   'x': 4.05,
#   'y': 4.07,
#   'z': 2.31},
#  {'index': 3,
#   's': 4,
#   'carat': 0.29,
#   'cut': 'Premium',
#   'color': 'I',
#   'clarity': 'VS2',
#   'depth': 62.4,
#   'table': 58.0,
#   'price': 334,
#   'x': 4.2,
#   'y': 4.23,
#   'z': 2.63},
#  {'index': 4,
#   's': 5,
#   'carat': 0.31,
#   'cut': 'Good',
#   'color': 'J',
#   'clarity': 'SI2',
#   'depth': 63.3,
#   'table': 58.0,
#   'price': 335,
#   'x': 4.34,
#   'y': 4.35,
#   'z': 2.75},
#  {'index': 5,
#   's': 6,
#   'carat': 0.24,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'VVS2',
#   'depth': 62.8,
#   'table': 57.0,
#   'price': 336,
#   'x': 3.94,
#   'y': 3.96,
#   'z': 2.48},
#  {'index': 6,
#   's': 7,
#   'carat': 0.24,
#   'cut': 'Very Good',
#   'color': 'I',
#   'clarity': 'VVS1',
#   'depth': 62.3,
#   'table': 57.0,
#   'price': 336,
#   'x': 3.95,
#   'y': 3.98,
#   'z': 2.47},
#  {'index': 7,
#   's': 8,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 61.9,
#   'table': 55.0,
#   'price': 337,
#   'x': 4.07,
#   'y': 4.11,
#   'z': 2.53},
#  {'index': 8,
#   's': 9,
#   'carat': 0.22,
#   'cut': 'Fair',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 65.1,
#   'table': 61.0,
#   'price': 337,
#   'x': 3.87,
#   'y': 3.78,
#   'z': 2.49},
#  {'index': 9,
#   's': 10,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VS1',
#   'depth': 59.4,
#   'table': 61.0,
#   'price': 338,
#   'x': 4.0,
#   'y': 4.05,
#   'z': 2.39},
#  {'index': 10,
#   's': 11,
#   'carat': 0.3,
#   'cut': 'Good',
#   'color': 'J',
#   'clarity': 'SI1',
#   'depth': 64.0,
#   'table': 55.0,
#   'price': 339,
#   'x': 4.25,
#   'y': 4.28,
#   'z': 2.73},
#  {'index': 11,
#   's': 12,
#   'carat': 0.23,
#   'cut': 'Ideal',
#   'color': 'J',
#   'clarity': 'VS1',
#   'depth': 62.8,
#   'table': 56.0,
#   'price': 340,
#   'x': 3.93,
#   'y': 3.9,
#   'z': 2.46},
#  {'index': 12,
#   's': 13,
#   'carat': 0.22,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 60.4,
#   'table': 61.0,
#   'price': 342,
#   'x': 3.88,
#   'y': 3.84,
#   'z': 2.33},
#  {'index': 13,
#   's': 14,
#   'carat': 0.31,
#   'cut': 'Ideal',
#   'color': 'J',
#   'clarity': 'SI2',
#   'depth': 62.2,
#   'table': 54.0,
#   'price': 344,
#   'x': 4.35,
#   'y': 4.37,
#   'z': 2.71},
#  {'index': 14,
#   's': 15,
#   'carat': 0.2,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI2',
#   'depth': 60.2,
#   'table': 62.0,
#   'price': 345,
#   'x': 3.79,
#   'y': 3.75,
#   'z': 2.27},
#  {'index': 15,
#   's': 16,
#   'carat': 0.32,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'I1',
#   'depth': 60.9,
#   'table': 58.0,
#   'price': 345,
#   'x': 4.38,
#   'y': 4.42,
#   'z': 2.68},
#  {'index': 16,
#   's': 17,
#   'carat': 0.3,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'SI2',
#   'depth': 62.0,
#   'table': 54.0,
#   'price': 348,
#   'x': 4.31,
#   'y': 4.34,
#   'z': 2.68},
#  {'index': 17,
#   's': 18,
#   'carat': 0.3,
#   'cut': 'Good',
#   'color': 'J',
#   'clarity': 'SI1',
#   'depth': 63.4,
#   'table': 54.0,
#   'price': 351,
#   'x': 4.23,
#   'y': 4.29,
#   'z': 2.7},
#  {'index': 18,
#   's': 19,
#   'carat': 0.3,
#   'cut': 'Good',
#   'color': 'J',
#   'clarity': 'SI1',
#   'depth': 63.8,
#   'table': 56.0,
#   'price': 351,
#   'x': 4.23,
#   'y': 4.26,
#   'z': 2.71},
#  {'index': 19,
#   's': 20,
#   'carat': 0.3,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'SI1',
#   'depth': 62.7,
#   'table': 59.0,
#   'price': 351,
#   'x': 4.21,
#   'y': 4.27,
#   'z': 2.66},
#  {'index': 20,
#   's': 21,
#   'carat': 0.3,
#   'cut': 'Good',
#   'color': 'I',
#   'clarity': 'SI2',
#   'depth': 63.3,
#   'table': 56.0,
#   'price': 351,
#   'x': 4.26,
#   'y': 4.3,
#   'z': 2.71},
#  {'index': 21,
#   's': 22,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 63.8,
#   'table': 55.0,
#   'price': 352,
#   'x': 3.85,
#   'y': 3.92,
#   'z': 2.48},
#  {'index': 22,
#   's': 23,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VS1',
#   'depth': 61.0,
#   'table': 57.0,
#   'price': 353,
#   'x': 3.94,
#   'y': 3.96,
#   'z': 2.41},
#  {'index': 23,
#   's': 24,
#   'carat': 0.31,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'SI1',
#   'depth': 59.4,
#   'table': 62.0,
#   'price': 353,
#   'x': 4.39,
#   'y': 4.43,
#   'z': 2.62},
#  {'index': 24,
#   's': 25,
#   'carat': 0.31,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'SI1',
#   'depth': 58.1,
#   'table': 62.0,
#   'price': 353,
#   'x': 4.44,
#   'y': 4.47,
#   'z': 2.59},
#  {'index': 25,
#   's': 26,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'VVS2',
#   'depth': 60.4,
#   'table': 58.0,
#   'price': 354,
#   'x': 3.97,
#   'y': 4.01,
#   'z': 2.41},
#  {'index': 26,
#   's': 27,
#   'carat': 0.24,
#   'cut': 'Premium',
#   'color': 'I',
#   'clarity': 'VS1',
#   'depth': 62.5,
#   'table': 57.0,
#   'price': 355,
#   'x': 3.97,
#   'y': 3.94,
#   'z': 2.47},
#  {'index': 27,
#   's': 28,
#   'carat': 0.3,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'VS2',
#   'depth': 62.2,
#   'table': 57.0,
#   'price': 357,
#   'x': 4.28,
#   'y': 4.3,
#   'z': 2.67},
#  {'index': 28,
#   's': 29,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 60.5,
#   'table': 61.0,
#   'price': 357,
#   'x': 3.96,
#   'y': 3.97,
#   'z': 2.4},
#  {'index': 29,
#   's': 30,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 60.9,
#   'table': 57.0,
#   'price': 357,
#   'x': 3.96,
#   'y': 3.99,
#   'z': 2.42},
#  {'index': 30,
#   's': 31,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 60.0,
#   'table': 57.0,
#   'price': 402,
#   'x': 4.0,
#   'y': 4.03,
#   'z': 2.41},
#  {'index': 31,
#   's': 32,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 59.8,
#   'table': 57.0,
#   'price': 402,
#   'x': 4.04,
#   'y': 4.06,
#   'z': 2.42},
#  {'index': 32,
#   's': 33,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS1',
#   'depth': 60.7,
#   'table': 59.0,
#   'price': 402,
#   'x': 3.97,
#   'y': 4.01,
#   'z': 2.42},
#  {'index': 33,
#   's': 34,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS1',
#   'depth': 59.5,
#   'table': 58.0,
#   'price': 402,
#   'x': 4.01,
#   'y': 4.06,
#   'z': 2.4},
#  {'index': 34,
#   's': 35,
#   'carat': 0.23,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VS1',
#   'depth': 61.9,
#   'table': 58.0,
#   'price': 402,
#   'x': 3.92,
#   'y': 3.96,
#   'z': 2.44},
#  {'index': 35,
#   's': 36,
#   'carat': 0.23,
#   'cut': 'Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 58.2,
#   'table': 59.0,
#   'price': 402,
#   'x': 4.06,
#   'y': 4.08,
#   'z': 2.37},
#  {'index': 36,
#   's': 37,
#   'carat': 0.23,
#   'cut': 'Good',
#   'color': 'E',
#   'clarity': 'VS1',
#   'depth': 64.1,
#   'table': 59.0,
#   'price': 402,
#   'x': 3.83,
#   'y': 3.85,
#   'z': 2.46},
#  {'index': 37,
#   's': 38,
#   'carat': 0.31,
#   'cut': 'Good',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 64.0,
#   'table': 54.0,
#   'price': 402,
#   'x': 4.29,
#   'y': 4.31,
#   'z': 2.75},
#  {'index': 38,
#   's': 39,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 60.8,
#   'table': 59.0,
#   'price': 403,
#   'x': 4.13,
#   'y': 4.16,
#   'z': 2.52},
#  {'index': 39,
#   's': 40,
#   'carat': 0.33,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'SI2',
#   'depth': 61.8,
#   'table': 55.0,
#   'price': 403,
#   'x': 4.49,
#   'y': 4.51,
#   'z': 2.78},
#  {'index': 40,
#   's': 41,
#   'carat': 0.33,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'SI2',
#   'depth': 61.2,
#   'table': 56.0,
#   'price': 403,
#   'x': 4.49,
#   'y': 4.5,
#   'z': 2.75},
#  {'index': 41,
#   's': 42,
#   'carat': 0.33,
#   'cut': 'Ideal',
#   'color': 'J',
#   'clarity': 'SI1',
#   'depth': 61.1,
#   'table': 56.0,
#   'price': 403,
#   'x': 4.49,
#   'y': 4.55,
#   'z': 2.76},
#  {'index': 42,
#   's': 43,
#   'carat': 0.26,
#   'cut': 'Good',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 65.2,
#   'table': 56.0,
#   'price': 403,
#   'x': 3.99,
#   'y': 4.02,
#   'z': 2.61},
#  {'index': 43,
#   's': 44,
#   'carat': 0.26,
#   'cut': 'Good',
#   'color': 'D',
#   'clarity': 'VS1',
#   'depth': 58.4,
#   'table': 63.0,
#   'price': 403,
#   'x': 4.19,
#   'y': 4.24,
#   'z': 2.46},
#  {'index': 44,
#   's': 45,
#   'carat': 0.32,
#   'cut': 'Good',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 63.1,
#   'table': 56.0,
#   'price': 403,
#   'x': 4.34,
#   'y': 4.37,
#   'z': 2.75},
#  {'index': 45,
#   's': 46,
#   'carat': 0.29,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 62.4,
#   'table': 58.0,
#   'price': 403,
#   'x': 4.24,
#   'y': 4.26,
#   'z': 2.65},
#  {'index': 46,
#   's': 47,
#   'carat': 0.32,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 61.8,
#   'table': 55.0,
#   'price': 403,
#   'x': 4.35,
#   'y': 4.42,
#   'z': 2.71},
#  {'index': 47,
#   's': 48,
#   'carat': 0.32,
#   'cut': 'Good',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 63.8,
#   'table': 56.0,
#   'price': 403,
#   'x': 4.36,
#   'y': 4.38,
#   'z': 2.79},
#  {'index': 48,
#   's': 49,
#   'carat': 0.25,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 63.3,
#   'table': 60.0,
#   'price': 404,
#   'x': 4.0,
#   'y': 4.03,
#   'z': 2.54},
#  {'index': 49,
#   's': 50,
#   'carat': 0.29,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 60.7,
#   'table': 60.0,
#   'price': 404,
#   'x': 4.33,
#   'y': 4.37,
#   'z': 2.64},
#  {'index': 50,
#   's': 51,
#   'carat': 0.24,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 60.9,
#   'table': 61.0,
#   'price': 404,
#   'x': 4.02,
#   'y': 4.03,
#   'z': 2.45},
#  {'index': 51,
#   's': 52,
#   'carat': 0.23,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 61.9,
#   'table': 54.0,
#   'price': 404,
#   'x': 3.93,
#   'y': 3.95,
#   'z': 2.44},
#  {'index': 52,
#   's': 53,
#   'carat': 0.32,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'SI1',
#   'depth': 60.9,
#   'table': 55.0,
#   'price': 404,
#   'x': 4.45,
#   'y': 4.48,
#   'z': 2.72},
#  {'index': 53,
#   's': 54,
#   'carat': 0.22,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 61.6,
#   'table': 58.0,
#   'price': 404,
#   'x': 3.93,
#   'y': 3.89,
#   'z': 2.41},
#  {'index': 54,
#   's': 55,
#   'carat': 0.22,
#   'cut': 'Premium',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 59.3,
#   'table': 62.0,
#   'price': 404,
#   'x': 3.91,
#   'y': 3.88,
#   'z': 2.31},
#  {'index': 55,
#   's': 56,
#   'carat': 0.3,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'SI2',
#   'depth': 61.0,
#   'table': 59.0,
#   'price': 405,
#   'x': 4.3,
#   'y': 4.33,
#   'z': 2.63},
#  {'index': 56,
#   's': 57,
#   'carat': 0.3,
#   'cut': 'Premium',
#   'color': 'J',
#   'clarity': 'SI2',
#   'depth': 59.3,
#   'table': 61.0,
#   'price': 405,
#   'x': 4.43,
#   'y': 4.38,
#   'z': 2.61},
#  {'index': 57,
#   's': 58,
#   'carat': 0.3,
#   'cut': 'Very Good',
#   'color': 'I',
#   'clarity': 'SI1',
#   'depth': 62.6,
#   'table': 57.0,
#   'price': 405,
#   'x': 4.25,
#   'y': 4.28,
#   'z': 2.67},
#  {'index': 58,
#   's': 59,
#   'carat': 0.3,
#   'cut': 'Very Good',
#   'color': 'I',
#   'clarity': 'SI1',
#   'depth': 63.0,
#   'table': 57.0,
#   'price': 405,
#   'x': 4.28,
#   'y': 4.32,
#   'z': 2.71},
#  {'index': 59,
#   's': 60,
#   'carat': 0.3,
#   'cut': 'Good',
#   'color': 'I',
#   'clarity': 'SI1',
#   'depth': 63.2,
#   'table': 55.0,
#   'price': 405,
#   'x': 4.25,
#   'y': 4.29,
#   'z': 2.7},
#  {'index': 60,
#   's': 61,
#   'carat': 0.35,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'VS1',
#   'depth': 60.9,
#   'table': 57.0,
#   'price': 552,
#   'x': 4.54,
#   'y': 4.59,
#   'z': 2.78},
#  {'index': 61,
#   's': 62,
#   'carat': 0.3,
#   'cut': 'Premium',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 62.6,
#   'table': 59.0,
#   'price': 552,
#   'x': 4.23,
#   'y': 4.27,
#   'z': 2.66},
#  {'index': 62,
#   's': 63,
#   'carat': 0.3,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 62.5,
#   'table': 57.0,
#   'price': 552,
#   'x': 4.29,
#   'y': 4.32,
#   'z': 2.69},
#  {'index': 63,
#   's': 64,
#   'carat': 0.3,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 62.1,
#   'table': 56.0,
#   'price': 552,
#   'x': 4.3,
#   'y': 4.33,
#   'z': 2.68},
#  {'index': 64,
#   's': 65,
#   'carat': 0.42,
#   'cut': 'Premium',
#   'color': 'I',
#   'clarity': 'SI2',
#   'depth': 61.5,
#   'table': 59.0,
#   'price': 552,
#   'x': 4.78,
#   'y': 4.84,
#   'z': 2.96},
#  {'index': 65,
#   's': 66,
#   'carat': 0.28,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VVS2',
#   'depth': 61.4,
#   'table': 56.0,
#   'price': 553,
#   'x': 4.19,
#   'y': 4.22,
#   'z': 2.58},
#  {'index': 66,
#   's': 67,
#   'carat': 0.32,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'VVS1',
#   'depth': 62.0,
#   'table': 55.3,
#   'price': 553,
#   'x': 4.39,
#   'y': 4.42,
#   'z': 2.73},
#  {'index': 67,
#   's': 68,
#   'carat': 0.31,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 63.3,
#   'table': 57.0,
#   'price': 553,
#   'x': 4.33,
#   'y': 4.3,
#   'z': 2.73},
#  {'index': 68,
#   's': 69,
#   'carat': 0.31,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 61.8,
#   'table': 58.0,
#   'price': 553,
#   'x': 4.35,
#   'y': 4.32,
#   'z': 2.68},
#  {'index': 69,
#   's': 70,
#   'carat': 0.24,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'VVS1',
#   'depth': 60.7,
#   'table': 58.0,
#   'price': 553,
#   'x': 4.01,
#   'y': 4.03,
#   'z': 2.44},
#  {'index': 70,
#   's': 71,
#   'carat': 0.24,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VVS1',
#   'depth': 61.5,
#   'table': 60.0,
#   'price': 553,
#   'x': 3.97,
#   'y': 4.0,
#   'z': 2.45},
#  {'index': 71,
#   's': 72,
#   'carat': 0.3,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 63.1,
#   'table': 56.0,
#   'price': 554,
#   'x': 4.29,
#   'y': 4.27,
#   'z': 2.7},
#  {'index': 72,
#   's': 73,
#   'carat': 0.3,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 62.9,
#   'table': 59.0,
#   'price': 554,
#   'x': 4.28,
#   'y': 4.24,
#   'z': 2.68},
#  {'index': 73,
#   's': 74,
#   'carat': 0.3,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 62.5,
#   'table': 57.0,
#   'price': 554,
#   'x': 4.29,
#   'y': 4.25,
#   'z': 2.67},
#  {'index': 74,
#   's': 75,
#   'carat': 0.3,
#   'cut': 'Good',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 63.7,
#   'table': 57.0,
#   'price': 554,
#   'x': 4.28,
#   'y': 4.26,
#   'z': 2.72},
#  {'index': 75,
#   's': 76,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VVS2',
#   'depth': 59.2,
#   'table': 60.0,
#   'price': 554,
#   'x': 4.19,
#   'y': 4.22,
#   'z': 2.49},
#  {'index': 76,
#   's': 77,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VVS2',
#   'depth': 59.9,
#   'table': 58.0,
#   'price': 554,
#   'x': 4.15,
#   'y': 4.23,
#   'z': 2.51},
#  {'index': 77,
#   's': 78,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VVS2',
#   'depth': 62.4,
#   'table': 54.0,
#   'price': 554,
#   'x': 4.08,
#   'y': 4.13,
#   'z': 2.56},
#  {'index': 78,
#   's': 79,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VVS2',
#   'depth': 62.8,
#   'table': 60.0,
#   'price': 554,
#   'x': 4.01,
#   'y': 4.05,
#   'z': 2.53},
#  {'index': 79,
#   's': 80,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VVS1',
#   'depth': 62.6,
#   'table': 59.0,
#   'price': 554,
#   'x': 4.06,
#   'y': 4.09,
#   'z': 2.55},
#  {'index': 80,
#   's': 81,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VVS1',
#   'depth': 63.4,
#   'table': 59.0,
#   'price': 554,
#   'x': 4.0,
#   'y': 4.04,
#   'z': 2.55},
#  {'index': 81,
#   's': 82,
#   'carat': 0.26,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VVS1',
#   'depth': 62.1,
#   'table': 60.0,
#   'price': 554,
#   'x': 4.03,
#   'y': 4.12,
#   'z': 2.53},
#  {'index': 82,
#   's': 83,
#   'carat': 0.26,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VVS2',
#   'depth': 62.9,
#   'table': 58.0,
#   'price': 554,
#   'x': 4.02,
#   'y': 4.06,
#   'z': 2.54},
#  {'index': 83,
#   's': 84,
#   'carat': 0.38,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'SI2',
#   'depth': 61.6,
#   'table': 56.0,
#   'price': 554,
#   'x': 4.65,
#   'y': 4.67,
#   'z': 2.87},
#  {'index': 84,
#   's': 85,
#   'carat': 0.26,
#   'cut': 'Good',
#   'color': 'E',
#   'clarity': 'VVS1',
#   'depth': 57.9,
#   'table': 60.0,
#   'price': 554,
#   'x': 4.22,
#   'y': 4.25,
#   'z': 2.45},
#  {'index': 85,
#   's': 86,
#   'carat': 0.24,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VVS1',
#   'depth': 62.3,
#   'table': 59.0,
#   'price': 554,
#   'x': 3.95,
#   'y': 3.92,
#   'z': 2.45},
#  {'index': 86,
#   's': 87,
#   'carat': 0.24,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'VVS1',
#   'depth': 61.2,
#   'table': 58.0,
#   'price': 554,
#   'x': 4.01,
#   'y': 3.96,
#   'z': 2.44},
#  {'index': 87,
#   's': 88,
#   'carat': 0.24,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'VVS1',
#   'depth': 60.8,
#   'table': 59.0,
#   'price': 554,
#   'x': 4.02,
#   'y': 4.0,
#   'z': 2.44},
#  {'index': 88,
#   's': 89,
#   'carat': 0.24,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'VVS2',
#   'depth': 60.7,
#   'table': 58.0,
#   'price': 554,
#   'x': 4.07,
#   'y': 4.04,
#   'z': 2.46},
#  {'index': 89,
#   's': 90,
#   'carat': 0.32,
#   'cut': 'Premium',
#   'color': 'I',
#   'clarity': 'SI1',
#   'depth': 62.9,
#   'table': 58.0,
#   'price': 554,
#   'x': 4.35,
#   'y': 4.33,
#   'z': 2.73},
#  {'index': 90,
#   's': 91,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 62.5,
#   'table': 57.0,
#   'price': 2757,
#   'x': 5.7,
#   'y': 5.72,
#   'z': 3.57},
#  {'index': 91,
#   's': 92,
#   'carat': 0.86,
#   'cut': 'Fair',
#   'color': 'E',
#   'clarity': 'SI2',
#   'depth': 55.1,
#   'table': 69.0,
#   'price': 2757,
#   'x': 6.45,
#   'y': 6.33,
#   'z': 3.52},
#  {'index': 92,
#   's': 93,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 61.6,
#   'table': 56.0,
#   'price': 2757,
#   'x': 5.7,
#   'y': 5.67,
#   'z': 3.5},
#  {'index': 93,
#   's': 94,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 62.4,
#   'table': 57.0,
#   'price': 2759,
#   'x': 5.68,
#   'y': 5.73,
#   'z': 3.56},
#  {'index': 94,
#   's': 95,
#   'carat': 0.78,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 63.8,
#   'table': 56.0,
#   'price': 2759,
#   'x': 5.81,
#   'y': 5.85,
#   'z': 3.72},
#  {'index': 95,
#   's': 96,
#   'carat': 0.7,
#   'cut': 'Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 57.5,
#   'table': 58.0,
#   'price': 2759,
#   'x': 5.85,
#   'y': 5.9,
#   'z': 3.38},
#  {'index': 96,
#   's': 97,
#   'carat': 0.7,
#   'cut': 'Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 59.4,
#   'table': 62.0,
#   'price': 2759,
#   'x': 5.71,
#   'y': 5.76,
#   'z': 3.4},
#  {'index': 97,
#   's': 98,
#   'carat': 0.96,
#   'cut': 'Fair',
#   'color': 'F',
#   'clarity': 'SI2',
#   'depth': 66.3,
#   'table': 62.0,
#   'price': 2759,
#   'x': 6.27,
#   'y': 5.95,
#   'z': 4.07},
#  {'index': 98,
#   's': 99,
#   'carat': 0.73,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.6,
#   'table': 59.0,
#   'price': 2760,
#   'x': 5.77,
#   'y': 5.78,
#   'z': 3.56},
#  {'index': 99,
#   's': 100,
#   'carat': 0.8,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 61.5,
#   'table': 58.0,
#   'price': 2760,
#   'x': 5.97,
#   'y': 5.93,
#   'z': 3.66},
#  {'index': 100,
#   's': 101,
#   'carat': 0.75,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 63.2,
#   'table': 56.0,
#   'price': 2760,
#   'x': 5.8,
#   'y': 5.75,
#   'z': 3.65},
#  {'index': 101,
#   's': 102,
#   'carat': 0.75,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 59.9,
#   'table': 54.0,
#   'price': 2760,
#   'x': 6.0,
#   'y': 5.96,
#   'z': 3.58},
#  {'index': 102,
#   's': 103,
#   'carat': 0.74,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 61.6,
#   'table': 55.0,
#   'price': 2760,
#   'x': 5.8,
#   'y': 5.85,
#   'z': 3.59},
#  {'index': 103,
#   's': 104,
#   'carat': 0.75,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 61.7,
#   'table': 58.0,
#   'price': 2760,
#   'x': 5.85,
#   'y': 5.79,
#   'z': 3.59},
#  {'index': 104,
#   's': 105,
#   'carat': 0.8,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'VS1',
#   'depth': 62.9,
#   'table': 56.0,
#   'price': 2760,
#   'x': 5.94,
#   'y': 5.87,
#   'z': 3.72},
#  {'index': 105,
#   's': 106,
#   'carat': 0.75,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 62.2,
#   'table': 55.0,
#   'price': 2760,
#   'x': 5.87,
#   'y': 5.8,
#   'z': 3.63},
#  {'index': 106,
#   's': 107,
#   'carat': 0.8,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 63.0,
#   'table': 59.0,
#   'price': 2760,
#   'x': 5.9,
#   'y': 5.81,
#   'z': 3.69},
#  {'index': 107,
#   's': 108,
#   'carat': 0.74,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'VVS2',
#   'depth': 62.3,
#   'table': 55.0,
#   'price': 2761,
#   'x': 5.77,
#   'y': 5.81,
#   'z': 3.61},
#  {'index': 108,
#   's': 109,
#   'carat': 0.81,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI2',
#   'depth': 58.8,
#   'table': 57.0,
#   'price': 2761,
#   'x': 6.14,
#   'y': 6.11,
#   'z': 3.6},
#  {'index': 109,
#   's': 110,
#   'carat': 0.59,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VVS2',
#   'depth': 62.0,
#   'table': 55.0,
#   'price': 2761,
#   'x': 5.38,
#   'y': 5.43,
#   'z': 3.35},
#  {'index': 110,
#   's': 111,
#   'carat': 0.8,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI2',
#   'depth': 61.4,
#   'table': 57.0,
#   'price': 2761,
#   'x': 5.96,
#   'y': 6.0,
#   'z': 3.67},
#  {'index': 111,
#   's': 112,
#   'carat': 0.74,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI2',
#   'depth': 62.2,
#   'table': 56.0,
#   'price': 2761,
#   'x': 5.8,
#   'y': 5.84,
#   'z': 3.62},
#  {'index': 112,
#   's': 113,
#   'carat': 0.9,
#   'cut': 'Premium',
#   'color': 'I',
#   'clarity': 'VS2',
#   'depth': 63.0,
#   'table': 58.0,
#   'price': 2761,
#   'x': 6.16,
#   'y': 6.12,
#   'z': 3.87},
#  {'index': 113,
#   's': 114,
#   'carat': 0.74,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 62.2,
#   'table': 59.0,
#   'price': 2762,
#   'x': 5.73,
#   'y': 5.82,
#   'z': 3.59},
#  {'index': 114,
#   's': 115,
#   'carat': 0.73,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 62.6,
#   'table': 56.0,
#   'price': 2762,
#   'x': 5.77,
#   'y': 5.74,
#   'z': 3.6},
#  {'index': 115,
#   's': 116,
#   'carat': 0.73,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 62.7,
#   'table': 53.0,
#   'price': 2762,
#   'x': 5.8,
#   'y': 5.75,
#   'z': 3.62},
#  {'index': 116,
#   's': 117,
#   'carat': 0.8,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'SI2',
#   'depth': 61.7,
#   'table': 58.0,
#   'price': 2762,
#   'x': 5.98,
#   'y': 5.94,
#   'z': 3.68},
#  {'index': 117,
#   's': 118,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 62.4,
#   'table': 54.0,
#   'price': 2762,
#   'x': 5.72,
#   'y': 5.76,
#   'z': 3.58},
#  {'index': 118,
#   's': 119,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 60.7,
#   'table': 58.0,
#   'price': 2762,
#   'x': 5.73,
#   'y': 5.76,
#   'z': 3.49},
#  {'index': 119,
#   's': 120,
#   'carat': 0.8,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI2',
#   'depth': 59.9,
#   'table': 59.0,
#   'price': 2762,
#   'x': 6.01,
#   'y': 6.07,
#   'z': 3.62},
#  {'index': 120,
#   's': 121,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 62.3,
#   'table': 56.0,
#   'price': 2762,
#   'x': 5.73,
#   'y': 5.69,
#   'z': 3.56},
#  {'index': 121,
#   's': 122,
#   'carat': 0.74,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 62.3,
#   'table': 54.0,
#   'price': 2762,
#   'x': 5.8,
#   'y': 5.83,
#   'z': 3.62},
#  {'index': 122,
#   's': 123,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 61.7,
#   'table': 63.0,
#   'price': 2762,
#   'x': 5.64,
#   'y': 5.61,
#   'z': 3.47},
#  {'index': 123,
#   's': 124,
#   'carat': 0.7,
#   'cut': 'Fair',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 64.5,
#   'table': 57.0,
#   'price': 2762,
#   'x': 5.57,
#   'y': 5.53,
#   'z': 3.58},
#  {'index': 124,
#   's': 125,
#   'carat': 0.7,
#   'cut': 'Fair',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 65.3,
#   'table': 55.0,
#   'price': 2762,
#   'x': 5.63,
#   'y': 5.58,
#   'z': 3.66},
#  {'index': 125,
#   's': 126,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 61.6,
#   'table': 60.0,
#   'price': 2762,
#   'x': 5.65,
#   'y': 5.59,
#   'z': 3.46},
#  {'index': 126,
#   's': 127,
#   'carat': 0.91,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 61.4,
#   'table': 56.0,
#   'price': 2763,
#   'x': 6.09,
#   'y': 5.97,
#   'z': 3.7},
#  {'index': 127,
#   's': 128,
#   'carat': 0.61,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VVS2',
#   'depth': 59.6,
#   'table': 57.0,
#   'price': 2763,
#   'x': 5.56,
#   'y': 5.58,
#   'z': 3.32},
#  {'index': 128,
#   's': 129,
#   'carat': 0.91,
#   'cut': 'Fair',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 64.4,
#   'table': 57.0,
#   'price': 2763,
#   'x': 6.11,
#   'y': 6.09,
#   'z': 3.93},
#  {'index': 129,
#   's': 130,
#   'carat': 0.91,
#   'cut': 'Fair',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 65.7,
#   'table': 60.0,
#   'price': 2763,
#   'x': 6.03,
#   'y': 5.99,
#   'z': 3.95},
#  {'index': 130,
#   's': 131,
#   'carat': 0.77,
#   'cut': 'Ideal',
#   'color': 'H',
#   'clarity': 'VS2',
#   'depth': 62.0,
#   'table': 56.0,
#   'price': 2763,
#   'x': 5.89,
#   'y': 5.86,
#   'z': 3.64},
#  {'index': 131,
#   's': 132,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 63.6,
#   'table': 58.0,
#   'price': 2764,
#   'x': 5.64,
#   'y': 5.68,
#   'z': 3.6},
#  {'index': 132,
#   's': 133,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 61.9,
#   'table': 59.0,
#   'price': 2764,
#   'x': 5.69,
#   'y': 5.72,
#   'z': 3.53},
#  {'index': 133,
#   's': 134,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 62.6,
#   'table': 60.0,
#   'price': 2765,
#   'x': 5.62,
#   'y': 5.65,
#   'z': 3.53},
#  {'index': 134,
#   's': 135,
#   'carat': 0.77,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VS1',
#   'depth': 61.3,
#   'table': 60.0,
#   'price': 2765,
#   'x': 5.88,
#   'y': 5.9,
#   'z': 3.61},
#  {'index': 135,
#   's': 136,
#   'carat': 0.63,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'VVS1',
#   'depth': 60.9,
#   'table': 60.0,
#   'price': 2765,
#   'x': 5.52,
#   'y': 5.55,
#   'z': 3.37},
#  {'index': 136,
#   's': 137,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 60.1,
#   'table': 62.0,
#   'price': 2765,
#   'x': 5.74,
#   'y': 5.77,
#   'z': 3.46},
#  {'index': 137,
#   's': 138,
#   'carat': 0.71,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 61.8,
#   'table': 59.0,
#   'price': 2765,
#   'x': 5.69,
#   'y': 5.73,
#   'z': 3.53},
#  {'index': 138,
#   's': 139,
#   'carat': 0.76,
#   'cut': 'Ideal',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 61.2,
#   'table': 57.0,
#   'price': 2765,
#   'x': 5.88,
#   'y': 5.91,
#   'z': 3.61},
#  {'index': 139,
#   's': 140,
#   'carat': 0.64,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VVS1',
#   'depth': 61.9,
#   'table': 56.0,
#   'price': 2766,
#   'x': 5.53,
#   'y': 5.56,
#   'z': 3.43},
#  {'index': 140,
#   's': 141,
#   'carat': 0.71,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 60.9,
#   'table': 57.0,
#   'price': 2766,
#   'x': 5.78,
#   'y': 5.75,
#   'z': 3.51},
#  {'index': 141,
#   's': 142,
#   'carat': 0.71,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 59.8,
#   'table': 56.0,
#   'price': 2766,
#   'x': 5.89,
#   'y': 5.81,
#   'z': 3.5},
#  {'index': 142,
#   's': 143,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 61.8,
#   'table': 55.0,
#   'price': 2767,
#   'x': 5.68,
#   'y': 5.72,
#   'z': 3.52},
#  {'index': 143,
#   's': 144,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 60.0,
#   'table': 57.0,
#   'price': 2767,
#   'x': 5.8,
#   'y': 5.87,
#   'z': 3.5},
#  {'index': 144,
#   's': 145,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 61.6,
#   'table': 55.0,
#   'price': 2767,
#   'x': 5.74,
#   'y': 5.76,
#   'z': 3.54},
#  {'index': 145,
#   's': 146,
#   'carat': 0.7,
#   'cut': 'Good',
#   'color': 'H',
#   'clarity': 'VVS2',
#   'depth': 62.1,
#   'table': 64.0,
#   'price': 2767,
#   'x': 5.62,
#   'y': 5.65,
#   'z': 3.5},
#  {'index': 146,
#   's': 147,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 63.3,
#   'table': 59.0,
#   'price': 2768,
#   'x': 5.52,
#   'y': 5.61,
#   'z': 3.52},
#  {'index': 147,
#   's': 148,
#   'carat': 0.73,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 60.2,
#   'table': 56.0,
#   'price': 2768,
#   'x': 5.83,
#   'y': 5.87,
#   'z': 3.52},
#  {'index': 148,
#   's': 149,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 61.1,
#   'table': 58.0,
#   'price': 2768,
#   'x': 5.66,
#   'y': 5.73,
#   'z': 3.48},
#  {'index': 149,
#   's': 150,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 60.9,
#   'table': 57.0,
#   'price': 2768,
#   'x': 5.73,
#   'y': 5.76,
#   'z': 3.5},
#  {'index': 150,
#   's': 151,
#   'carat': 0.71,
#   'cut': 'Premium',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 61.7,
#   'table': 59.0,
#   'price': 2768,
#   'x': 5.71,
#   'y': 5.67,
#   'z': 3.51},
#  {'index': 151,
#   's': 152,
#   'carat': 0.74,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'SI1',
#   'depth': 61.3,
#   'table': 56.0,
#   'price': 2769,
#   'x': 5.82,
#   'y': 5.86,
#   'z': 3.57},
#  {'index': 152,
#   's': 153,
#   'carat': 0.71,
#   'cut': 'Premium',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 62.5,
#   'table': 60.0,
#   'price': 2770,
#   'x': 5.65,
#   'y': 5.61,
#   'z': 3.52},
#  {'index': 153,
#   's': 154,
#   'carat': 0.73,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 61.4,
#   'table': 59.0,
#   'price': 2770,
#   'x': 5.83,
#   'y': 5.76,
#   'z': 3.56},
#  {'index': 154,
#   's': 155,
#   'carat': 0.76,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 62.9,
#   'table': 57.0,
#   'price': 2770,
#   'x': 5.79,
#   'y': 5.81,
#   'z': 3.65},
#  {'index': 155,
#   's': 156,
#   'carat': 0.76,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 62.4,
#   'table': 57.0,
#   'price': 2770,
#   'x': 5.78,
#   'y': 5.83,
#   'z': 3.62},
#  {'index': 156,
#   's': 157,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 60.7,
#   'table': 56.0,
#   'price': 2770,
#   'x': 5.77,
#   'y': 5.8,
#   'z': 3.51},
#  {'index': 157,
#   's': 158,
#   'carat': 0.73,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 60.7,
#   'table': 58.0,
#   'price': 2770,
#   'x': 5.87,
#   'y': 5.82,
#   'z': 3.55},
#  {'index': 158,
#   's': 159,
#   'carat': 0.73,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 61.5,
#   'table': 58.0,
#   'price': 2770,
#   'x': 5.79,
#   'y': 5.75,
#   'z': 3.55},
#  {'index': 159,
#   's': 160,
#   'carat': 0.73,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 59.9,
#   'table': 57.0,
#   'price': 2770,
#   'x': 5.92,
#   'y': 5.89,
#   'z': 3.54},
#  {'index': 160,
#   's': 161,
#   'carat': 0.73,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 59.2,
#   'table': 59.0,
#   'price': 2770,
#   'x': 5.92,
#   'y': 5.87,
#   'z': 3.49},
#  {'index': 161,
#   's': 162,
#   'carat': 0.72,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VVS2',
#   'depth': 60.3,
#   'table': 56.0,
#   'price': 2771,
#   'x': 5.81,
#   'y': 5.83,
#   'z': 3.51},
#  {'index': 162,
#   's': 163,
#   'carat': 0.73,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 61.7,
#   'table': 60.0,
#   'price': 2771,
#   'x': 5.79,
#   'y': 5.82,
#   'z': 3.58},
#  {'index': 163,
#   's': 164,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 61.9,
#   'table': 57.0,
#   'price': 2771,
#   'x': 5.73,
#   'y': 5.77,
#   'z': 3.56},
#  {'index': 164,
#   's': 165,
#   'carat': 0.79,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI2',
#   'depth': 61.9,
#   'table': 55.0,
#   'price': 2771,
#   'x': 5.97,
#   'y': 5.92,
#   'z': 3.68},
#  {'index': 165,
#   's': 166,
#   'carat': 0.73,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VVS1',
#   'depth': 60.4,
#   'table': 59.0,
#   'price': 2772,
#   'x': 5.83,
#   'y': 5.89,
#   'z': 3.54},
#  {'index': 166,
#   's': 167,
#   'carat': 0.8,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'SI2',
#   'depth': 61.0,
#   'table': 57.0,
#   'price': 2772,
#   'x': 6.01,
#   'y': 6.03,
#   'z': 3.67},
#  {'index': 167,
#   's': 168,
#   'carat': 0.58,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VVS1',
#   'depth': 61.5,
#   'table': 55.0,
#   'price': 2772,
#   'x': 5.39,
#   'y': 5.44,
#   'z': 3.33},
#  {'index': 168,
#   's': 169,
#   'carat': 0.58,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VVS1',
#   'depth': 61.7,
#   'table': 56.0,
#   'price': 2772,
#   'x': 5.33,
#   'y': 5.37,
#   'z': 3.3},
#  {'index': 169,
#   's': 170,
#   'carat': 0.71,
#   'cut': 'Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 59.2,
#   'table': 61.0,
#   'price': 2772,
#   'x': 5.8,
#   'y': 5.88,
#   'z': 3.46},
#  {'index': 170,
#   's': 171,
#   'carat': 0.75,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 61.3,
#   'table': 56.0,
#   'price': 2773,
#   'x': 5.85,
#   'y': 5.89,
#   'z': 3.6},
#  {'index': 171,
#   's': 172,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 58.0,
#   'table': 62.0,
#   'price': 2773,
#   'x': 5.87,
#   'y': 5.78,
#   'z': 3.38},
#  {'index': 172,
#   's': 173,
#   'carat': 1.17,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'I1',
#   'depth': 60.2,
#   'table': 61.0,
#   'price': 2774,
#   'x': 6.83,
#   'y': 6.9,
#   'z': 4.13},
#  {'index': 173,
#   's': 174,
#   'carat': 0.6,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VS1',
#   'depth': 61.7,
#   'table': 55.0,
#   'price': 2774,
#   'x': 5.41,
#   'y': 5.44,
#   'z': 3.35},
#  {'index': 174,
#   's': 175,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 62.7,
#   'table': 55.0,
#   'price': 2774,
#   'x': 5.68,
#   'y': 5.74,
#   'z': 3.58},
#  {'index': 175,
#   's': 176,
#   'carat': 0.83,
#   'cut': 'Good',
#   'color': 'I',
#   'clarity': 'VS2',
#   'depth': 64.6,
#   'table': 54.0,
#   'price': 2774,
#   'x': 5.85,
#   'y': 5.88,
#   'z': 3.79},
#  {'index': 176,
#   's': 177,
#   'carat': 0.74,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 61.3,
#   'table': 61.0,
#   'price': 2775,
#   'x': 5.8,
#   'y': 5.84,
#   'z': 3.57},
#  {'index': 177,
#   's': 178,
#   'carat': 0.72,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 63.7,
#   'table': 56.4,
#   'price': 2776,
#   'x': 5.62,
#   'y': 5.69,
#   'z': 3.61},
#  {'index': 178,
#   's': 179,
#   'carat': 0.71,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 62.7,
#   'table': 58.0,
#   'price': 2776,
#   'x': 5.74,
#   'y': 5.68,
#   'z': 3.58},
#  {'index': 179,
#   's': 180,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 62.2,
#   'table': 57.0,
#   'price': 2776,
#   'x': 5.79,
#   'y': 5.62,
#   'z': 3.55},
#  {'index': 180,
#   's': 181,
#   'carat': 0.54,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VVS2',
#   'depth': 61.6,
#   'table': 56.0,
#   'price': 2776,
#   'x': 5.25,
#   'y': 5.27,
#   'z': 3.24},
#  {'index': 181,
#   's': 182,
#   'carat': 0.54,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VVS2',
#   'depth': 61.5,
#   'table': 57.0,
#   'price': 2776,
#   'x': 5.24,
#   'y': 5.26,
#   'z': 3.23},
#  {'index': 182,
#   's': 183,
#   'carat': 0.72,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 61.8,
#   'table': 56.0,
#   'price': 2776,
#   'x': 5.72,
#   'y': 5.75,
#   'z': 3.55},
#  {'index': 183,
#   's': 184,
#   'carat': 0.72,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 60.7,
#   'table': 56.0,
#   'price': 2776,
#   'x': 5.79,
#   'y': 5.82,
#   'z': 3.53},
#  {'index': 184,
#   's': 185,
#   'carat': 0.72,
#   'cut': 'Good',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 59.7,
#   'table': 60.5,
#   'price': 2776,
#   'x': 5.8,
#   'y': 5.84,
#   'z': 3.47},
#  {'index': 185,
#   's': 186,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 60.5,
#   'table': 56.0,
#   'price': 2776,
#   'x': 5.8,
#   'y': 5.76,
#   'z': 3.5},
#  {'index': 186,
#   's': 187,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VS1',
#   'depth': 62.7,
#   'table': 58.0,
#   'price': 2777,
#   'x': 5.66,
#   'y': 5.73,
#   'z': 3.57},
#  {'index': 187,
#   's': 188,
#   'carat': 0.71,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 62.1,
#   'table': 58.0,
#   'price': 2777,
#   'x': 5.67,
#   'y': 5.7,
#   'z': 3.53},
#  {'index': 188,
#   's': 189,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 62.8,
#   'table': 57.0,
#   'price': 2777,
#   'x': 5.64,
#   'y': 5.69,
#   'z': 3.56},
#  {'index': 189,
#   's': 190,
#   'carat': 0.71,
#   'cut': 'Good',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 63.8,
#   'table': 58.0,
#   'price': 2777,
#   'x': 5.61,
#   'y': 5.64,
#   'z': 3.59},
#  {'index': 190,
#   's': 191,
#   'carat': 0.71,
#   'cut': 'Good',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 57.8,
#   'table': 60.0,
#   'price': 2777,
#   'x': 5.87,
#   'y': 5.9,
#   'z': 3.4},
#  {'index': 191,
#   's': 192,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 62.1,
#   'table': 55.0,
#   'price': 2777,
#   'x': 5.7,
#   'y': 5.67,
#   'z': 3.53},
#  {'index': 192,
#   's': 193,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 61.1,
#   'table': 60.0,
#   'price': 2777,
#   'x': 5.71,
#   'y': 5.64,
#   'z': 3.47},
#  {'index': 193,
#   's': 194,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 60.0,
#   'table': 59.0,
#   'price': 2777,
#   'x': 5.79,
#   'y': 5.75,
#   'z': 3.46},
#  {'index': 194,
#   's': 195,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.2,
#   'table': 57.0,
#   'price': 2777,
#   'x': 5.73,
#   'y': 5.68,
#   'z': 3.49},
#  {'index': 195,
#   's': 196,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 62.7,
#   'table': 59.0,
#   'price': 2777,
#   'x': 5.67,
#   'y': 5.63,
#   'z': 3.54},
#  {'index': 196,
#   's': 197,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.0,
#   'table': 57.0,
#   'price': 2777,
#   'x': 5.73,
#   'y': 5.68,
#   'z': 3.48},
#  {'index': 197,
#   's': 198,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.0,
#   'table': 58.0,
#   'price': 2777,
#   'x': 5.78,
#   'y': 5.72,
#   'z': 3.51},
#  {'index': 198,
#   's': 199,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.4,
#   'table': 57.0,
#   'price': 2777,
#   'x': 5.76,
#   'y': 5.7,
#   'z': 3.52},
#  {'index': 199,
#   's': 200,
#   'carat': 0.72,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 61.8,
#   'table': 61.0,
#   'price': 2777,
#   'x': 5.82,
#   'y': 5.71,
#   'z': 3.56},
#  {'index': 200,
#   's': 201,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 59.9,
#   'table': 63.0,
#   'price': 2777,
#   'x': 5.76,
#   'y': 5.7,
#   'z': 3.43},
#  {'index': 201,
#   's': 202,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.3,
#   'table': 58.0,
#   'price': 2777,
#   'x': 5.71,
#   'y': 5.68,
#   'z': 3.49},
#  {'index': 202,
#   's': 203,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 60.5,
#   'table': 58.0,
#   'price': 2777,
#   'x': 5.77,
#   'y': 5.74,
#   'z': 3.48},
#  {'index': 203,
#   's': 204,
#   'carat': 0.7,
#   'cut': 'Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 64.1,
#   'table': 59.0,
#   'price': 2777,
#   'x': 5.64,
#   'y': 5.59,
#   'z': 3.6},
#  {'index': 204,
#   's': 205,
#   'carat': 0.98,
#   'cut': 'Fair',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 67.9,
#   'table': 60.0,
#   'price': 2777,
#   'x': 6.05,
#   'y': 5.97,
#   'z': 4.08},
#  {'index': 205,
#   's': 206,
#   'carat': 0.78,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 62.4,
#   'table': 58.0,
#   'price': 2777,
#   'x': 5.83,
#   'y': 5.8,
#   'z': 3.63},
#  {'index': 206,
#   's': 207,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 63.2,
#   'table': 60.0,
#   'price': 2777,
#   'x': 5.6,
#   'y': 5.51,
#   'z': 3.51},
#  {'index': 207,
#   's': 208,
#   'carat': 0.52,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VVS1',
#   'depth': 61.3,
#   'table': 55.0,
#   'price': 2778,
#   'x': 5.19,
#   'y': 5.22,
#   'z': 3.19},
#  {'index': 208,
#   's': 209,
#   'carat': 0.73,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VS2',
#   'depth': 60.8,
#   'table': 56.0,
#   'price': 2779,
#   'x': 5.82,
#   'y': 5.84,
#   'z': 3.55},
#  {'index': 209,
#   's': 210,
#   'carat': 0.74,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.7,
#   'table': 56.0,
#   'price': 2779,
#   'x': 5.84,
#   'y': 5.8,
#   'z': 3.59},
#  {'index': 210,
#   's': 211,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 63.6,
#   'table': 57.0,
#   'price': 2780,
#   'x': 5.61,
#   'y': 5.65,
#   'z': 3.58},
#  {'index': 211,
#   's': 212,
#   'carat': 0.77,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 61.2,
#   'table': 58.0,
#   'price': 2780,
#   'x': 5.9,
#   'y': 5.93,
#   'z': 3.62},
#  {'index': 212,
#   's': 213,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 62.1,
#   'table': 54.0,
#   'price': 2780,
#   'x': 5.68,
#   'y': 5.72,
#   'z': 3.54},
#  {'index': 213,
#   's': 214,
#   'carat': 0.74,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 61.5,
#   'table': 55.0,
#   'price': 2780,
#   'x': 5.81,
#   'y': 5.86,
#   'z': 3.59},
#  {'index': 214,
#   's': 215,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 61.4,
#   'table': 59.0,
#   'price': 2780,
#   'x': 5.64,
#   'y': 5.73,
#   'z': 3.49},
#  {'index': 215,
#   's': 216,
#   'carat': 1.01,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'I1',
#   'depth': 61.8,
#   'table': 60.0,
#   'price': 2781,
#   'x': 6.39,
#   'y': 6.36,
#   'z': 3.94},
#  {'index': 216,
#   's': 217,
#   'carat': 0.77,
#   'cut': 'Ideal',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 62.2,
#   'table': 56.0,
#   'price': 2781,
#   'x': 5.83,
#   'y': 5.88,
#   'z': 3.64},
#  {'index': 217,
#   's': 218,
#   'carat': 0.78,
#   'cut': 'Ideal',
#   'color': 'H',
#   'clarity': 'SI1',
#   'depth': 61.2,
#   'table': 56.0,
#   'price': 2781,
#   'x': 5.92,
#   'y': 5.99,
#   'z': 3.64},
#  {'index': 218,
#   's': 219,
#   'carat': 0.72,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VS1',
#   'depth': 60.6,
#   'table': 63.0,
#   'price': 2782,
#   'x': 5.83,
#   'y': 5.76,
#   'z': 3.51},
#  {'index': 219,
#   's': 220,
#   'carat': 0.53,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VVS2',
#   'depth': 57.5,
#   'table': 64.0,
#   'price': 2782,
#   'x': 5.34,
#   'y': 5.37,
#   'z': 3.08},
#  {'index': 220,
#   's': 221,
#   'carat': 0.76,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 61.3,
#   'table': 56.0,
#   'price': 2782,
#   'x': 5.9,
#   'y': 5.94,
#   'z': 3.63},
#  {'index': 221,
#   's': 222,
#   'carat': 0.7,
#   'cut': 'Good',
#   'color': 'E',
#   'clarity': 'VS1',
#   'depth': 57.2,
#   'table': 62.0,
#   'price': 2782,
#   'x': 5.81,
#   'y': 5.77,
#   'z': 3.31},
#  {'index': 222,
#   's': 223,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'VS1',
#   'depth': 62.9,
#   'table': 60.0,
#   'price': 2782,
#   'x': 5.62,
#   'y': 5.54,
#   'z': 3.51},
#  {'index': 223,
#   's': 224,
#   'carat': 0.75,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 63.1,
#   'table': 58.0,
#   'price': 2782,
#   'x': 5.78,
#   'y': 5.73,
#   'z': 3.63},
#  {'index': 224,
#   's': 225,
#   'carat': 0.72,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 60.8,
#   'table': 57.0,
#   'price': 2782,
#   'x': 5.76,
#   'y': 5.75,
#   'z': 3.5},
#  {'index': 225,
#   's': 226,
#   'carat': 0.72,
#   'cut': 'Premium',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 62.7,
#   'table': 59.0,
#   'price': 2782,
#   'x': 5.73,
#   'y': 5.69,
#   'z': 3.58},
#  {'index': 226,
#   's': 227,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 62.8,
#   'table': 60.0,
#   'price': 2782,
#   'x': 5.68,
#   'y': 5.66,
#   'z': 3.56},
#  {'index': 227,
#   's': 228,
#   'carat': 0.84,
#   'cut': 'Fair',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 55.1,
#   'table': 67.0,
#   'price': 2782,
#   'x': 6.39,
#   'y': 6.2,
#   'z': 3.47},
#  {'index': 228,
#   's': 229,
#   'carat': 0.75,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 61.4,
#   'table': 59.0,
#   'price': 2782,
#   'x': 5.88,
#   'y': 5.85,
#   'z': 3.6},
#  {'index': 229,
#   's': 230,
#   'carat': 0.52,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'IF',
#   'depth': 62.2,
#   'table': 55.0,
#   'price': 2783,
#   'x': 5.14,
#   'y': 5.18,
#   'z': 3.21},
#  {'index': 230,
#   's': 231,
#   'carat': 0.72,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 63.0,
#   'table': 54.0,
#   'price': 2784,
#   'x': 5.69,
#   'y': 5.73,
#   'z': 3.6},
#  {'index': 231,
#   's': 232,
#   'carat': 0.79,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VS1',
#   'depth': 63.7,
#   'table': 56.0,
#   'price': 2784,
#   'x': 5.85,
#   'y': 5.92,
#   'z': 3.75},
#  {'index': 232,
#   's': 233,
#   'carat': 0.72,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 63.6,
#   'table': 58.0,
#   'price': 2787,
#   'x': 5.66,
#   'y': 5.69,
#   'z': 3.61},
#  {'index': 233,
#   's': 234,
#   'carat': 0.51,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VVS1',
#   'depth': 62.0,
#   'table': 57.0,
#   'price': 2787,
#   'x': 5.11,
#   'y': 5.15,
#   'z': 3.18},
#  {'index': 234,
#   's': 235,
#   'carat': 0.64,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'VS1',
#   'depth': 61.5,
#   'table': 56.0,
#   'price': 2787,
#   'x': 5.54,
#   'y': 5.55,
#   'z': 3.41},
#  {'index': 235,
#   's': 236,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VVS1',
#   'depth': 60.5,
#   'table': 60.0,
#   'price': 2788,
#   'x': 5.74,
#   'y': 5.77,
#   'z': 3.48},
#  {'index': 236,
#   's': 237,
#   'carat': 0.83,
#   'cut': 'Very Good',
#   'color': 'I',
#   'clarity': 'VS1',
#   'depth': 61.1,
#   'table': 60.0,
#   'price': 2788,
#   'x': 6.07,
#   'y': 6.1,
#   'z': 3.72},
#  {'index': 237,
#   's': 238,
#   'carat': 0.76,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'VVS2',
#   'depth': 61.8,
#   'table': 56.0,
#   'price': 2788,
#   'x': 5.85,
#   'y': 5.87,
#   'z': 3.62},
#  {'index': 238,
#   's': 239,
#   'carat': 0.71,
#   'cut': 'Good',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 63.3,
#   'table': 56.0,
#   'price': 2788,
#   'x': 5.64,
#   'y': 5.68,
#   'z': 3.58},
#  {'index': 239,
#   's': 240,
#   'carat': 0.77,
#   'cut': 'Good',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 59.4,
#   'table': 64.0,
#   'price': 2788,
#   'x': 5.97,
#   'y': 5.92,
#   'z': 3.53},
#  {'index': 240,
#   's': 241,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 62.5,
#   'table': 55.0,
#   'price': 2788,
#   'x': 5.71,
#   'y': 5.65,
#   'z': 3.55},
#  {'index': 241,
#   's': 242,
#   'carat': 1.01,
#   'cut': 'Fair',
#   'color': 'E',
#   'clarity': 'I1',
#   'depth': 64.5,
#   'table': 58.0,
#   'price': 2788,
#   'x': 6.29,
#   'y': 6.21,
#   'z': 4.03},
#  {'index': 242,
#   's': 243,
#   'carat': 1.01,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 62.7,
#   'table': 59.0,
#   'price': 2788,
#   'x': 6.31,
#   'y': 6.22,
#   'z': 3.93},
#  {'index': 243,
#   's': 244,
#   'carat': 0.77,
#   'cut': 'Good',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 64.2,
#   'table': 52.0,
#   'price': 2789,
#   'x': 5.81,
#   'y': 5.77,
#   'z': 3.72},
#  {'index': 244,
#   's': 245,
#   'carat': 0.76,
#   'cut': 'Good',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 63.7,
#   'table': 54.0,
#   'price': 2789,
#   'x': 5.76,
#   'y': 5.85,
#   'z': 3.7},
#  {'index': 245,
#   's': 246,
#   'carat': 0.76,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 60.4,
#   'table': 58.0,
#   'price': 2789,
#   'x': 5.92,
#   'y': 5.94,
#   'z': 3.58},
#  {'index': 246,
#   's': 247,
#   'carat': 0.76,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.8,
#   'table': 58.0,
#   'price': 2789,
#   'x': 5.82,
#   'y': 5.86,
#   'z': 3.61},
#  {'index': 247,
#   's': 248,
#   'carat': 1.05,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'SI2',
#   'depth': 63.2,
#   'table': 56.0,
#   'price': 2789,
#   'x': 6.49,
#   'y': 6.45,
#   'z': 4.09},
#  {'index': 248,
#   's': 249,
#   'carat': 0.81,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 61.6,
#   'table': 56.0,
#   'price': 2789,
#   'x': 5.97,
#   'y': 6.01,
#   'z': 3.69},
#  {'index': 249,
#   's': 250,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.6,
#   'table': 56.0,
#   'price': 2789,
#   'x': 5.72,
#   'y': 5.75,
#   'z': 3.53},
#  {'index': 250,
#   's': 251,
#   'carat': 0.55,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'IF',
#   'depth': 60.9,
#   'table': 57.0,
#   'price': 2789,
#   'x': 5.28,
#   'y': 5.3,
#   'z': 3.22},
#  {'index': 251,
#   's': 252,
#   'carat': 0.81,
#   'cut': 'Good',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 61.0,
#   'table': 61.0,
#   'price': 2789,
#   'x': 5.94,
#   'y': 5.99,
#   'z': 3.64},
#  {'index': 252,
#   's': 253,
#   'carat': 0.63,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'VVS2',
#   'depth': 62.1,
#   'table': 57.0,
#   'price': 2789,
# ...
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 61.0,
#   'table': 56.0,
#   'price': 2879,
#   'x': 6.13,
#   'y': 6.1,
#   'z': 3.73},
#  {'index': 917,
#   's': 918,
#   'carat': 0.84,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 62.3,
#   'table': 55.0,
#   'price': 2879,
#   'x': 6.08,
#   'y': 6.03,
#   'z': 3.77},
#  {'index': 918,
#   's': 919,
#   'carat': 1.02,
#   'cut': 'Ideal',
#   'color': 'J',
#   'clarity': 'SI2',
#   'depth': 60.3,
#   'table': 54.0,
#   'price': 2879,
#   'x': 6.53,
#   'y': 6.5,
#   'z': 3.93},
#  {'index': 919,
#   's': 920,
#   'carat': 0.72,
#   'cut': 'Fair',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 56.9,
#   'table': 69.0,
#   'price': 2879,
#   'x': 5.93,
#   'y': 5.77,
#   'z': 3.33},
#  {'index': 920,
#   's': 921,
#   'carat': 0.72,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 62.0,
#   'table': 56.0,
#   'price': 2879,
#   'x': 5.76,
#   'y': 5.73,
#   'z': 3.56},
#  {'index': 921,
#   's': 922,
#   'carat': 0.92,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'SI2',
#   'depth': 58.7,
#   'table': 61.0,
#   'price': 2880,
#   'x': 6.34,
#   'y': 6.43,
#   'z': 3.75},
#  {'index': 922,
#   's': 923,
#   'carat': 0.74,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 63.9,
#   'table': 57.0,
#   'price': 2880,
#   'x': 5.72,
#   'y': 5.74,
#   'z': 3.66},
#  {'index': 923,
#   's': 924,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'H',
#   'clarity': 'VVS1',
#   'depth': 62.0,
#   'table': 55.0,
#   'price': 2881,
#   'x': 5.74,
#   'y': 5.71,
#   'z': 3.55},
#  {'index': 924,
#   's': 925,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 60.0,
#   'table': 59.0,
#   'price': 2881,
#   'x': 5.84,
#   'y': 5.83,
#   'z': 3.5},
#  {'index': 925,
#   's': 926,
#   'carat': 1.05,
#   'cut': 'Premium',
#   'color': 'H',
#   'clarity': 'I1',
#   'depth': 62.0,
#   'table': 59.0,
#   'price': 2881,
#   'x': 6.5,
#   'y': 6.47,
#   'z': 4.02},
#  {'index': 926,
#   's': 927,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'IF',
#   'depth': 62.8,
#   'table': 56.0,
#   'price': 2882,
#   'x': 5.62,
#   'y': 5.65,
#   'z': 3.54},
#  {'index': 927,
#   's': 928,
#   'carat': 0.54,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VVS1',
#   'depth': 61.8,
#   'table': 56.0,
#   'price': 2882,
#   'x': 5.23,
#   'y': 5.26,
#   'z': 3.24},
#  {'index': 928,
#   's': 929,
#   'carat': 0.73,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 59.9,
#   'table': 58.0,
#   'price': 2882,
#   'x': 5.87,
#   'y': 5.84,
#   'z': 3.51},
#  {'index': 929,
#   's': 930,
#   'carat': 0.88,
#   'cut': 'Fair',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 56.6,
#   'table': 65.0,
#   'price': 2882,
#   'x': 6.39,
#   'y': 6.32,
#   'z': 3.6},
#  {'index': 930,
#   's': 931,
#   'carat': 0.73,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 58.7,
#   'table': 57.0,
#   'price': 2882,
#   'x': 5.97,
#   'y': 5.92,
#   'z': 3.49},
#  {'index': 931,
#   's': 932,
#   'carat': 0.72,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 61.8,
#   'table': 56.0,
#   'price': 2883,
#   'x': 5.75,
#   'y': 5.81,
#   'z': 3.57},
#  {'index': 932,
#   's': 933,
#   'carat': 0.9,
#   'cut': 'Good',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 62.7,
#   'table': 64.0,
#   'price': 2883,
#   'x': 6.09,
#   'y': 6.0,
#   'z': 3.79},
#  {'index': 933,
#   's': 934,
#   'carat': 0.9,
#   'cut': 'Fair',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 65.0,
#   'table': 61.0,
#   'price': 2883,
#   'x': 6.01,
#   'y': 5.96,
#   'z': 3.89},
#  {'index': 934,
#   's': 935,
#   'carat': 1.03,
#   'cut': 'Fair',
#   'color': 'I',
#   'clarity': 'SI2',
#   'depth': 65.3,
#   'table': 55.0,
#   'price': 2884,
#   'x': 6.32,
#   'y': 6.27,
#   'z': 4.11},
#  {'index': 935,
#   's': 936,
#   'carat': 0.84,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 63.8,
#   'table': 57.0,
#   'price': 2885,
#   'x': 5.95,
#   'y': 6.0,
#   'z': 3.81},
#  {'index': 936,
#   's': 937,
#   'carat': 1.01,
#   'cut': 'Premium',
#   'color': 'I',
#   'clarity': 'SI1',
#   'depth': 62.7,
#   'table': 60.0,
#   'price': 2885,
#   'x': 6.36,
#   'y': 6.27,
#   'z': 3.96},
#  {'index': 937,
#   's': 938,
#   'carat': 0.77,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 61.5,
#   'table': 55.0,
#   'price': 2885,
#   'x': 5.9,
#   'y': 5.93,
#   'z': 3.64},
#  {'index': 938,
#   's': 939,
#   'carat': 0.8,
#   'cut': 'Fair',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 56.3,
#   'table': 63.0,
#   'price': 2885,
#   'x': 6.22,
#   'y': 6.14,
#   'z': 3.48},
#  {'index': 939,
#   's': 940,
#   'carat': 0.9,
#   'cut': 'Fair',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 66.9,
#   'table': 57.0,
#   'price': 2885,
#   'x': 6.02,
#   'y': 5.9,
#   'z': 3.99},
#  {'index': 940,
#   's': 941,
#   'carat': 0.73,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.4,
#   'table': 56.0,
#   'price': 2886,
#   'x': 5.79,
#   'y': 5.81,
#   'z': 3.56},
#  {'index': 941,
#   's': 942,
#   'carat': 0.72,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 62.7,
#   'table': 55.0,
#   'price': 2886,
#   'x': 5.64,
#   'y': 5.69,
#   'z': 3.55},
#  {'index': 942,
#   's': 943,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 62.4,
#   'table': 54.0,
#   'price': 2887,
#   'x': 5.71,
#   'y': 5.79,
#   'z': 3.59},
#  {'index': 943,
#   's': 944,
#   'carat': 0.7,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'VS1',
#   'depth': 62.6,
#   'table': 59.0,
#   'price': 2887,
#   'x': 5.66,
#   'y': 5.69,
#   'z': 3.55},
#  {'index': 944,
#   's': 945,
#   'carat': 0.79,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'VS1',
#   'depth': 61.7,
#   'table': 59.0,
#   'price': 2888,
#   'x': 5.93,
#   'y': 5.96,
#   'z': 3.67},
#  {'index': 945,
#   's': 946,
#   'carat': 0.72,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'VVS2',
#   'depth': 62.5,
#   'table': 58.0,
#   'price': 2889,
#   'x': 5.68,
#   'y': 5.72,
#   'z': 3.56},
#  {'index': 946,
#   's': 947,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 63.5,
#   'table': 54.0,
#   'price': 2889,
#   'x': 5.62,
#   'y': 5.66,
#   'z': 3.58},
#  {'index': 947,
#   's': 948,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 62.2,
#   'table': 58.0,
#   'price': 2889,
#   'x': 5.64,
#   'y': 5.75,
#   'z': 3.54},
#  {'index': 948,
#   's': 949,
#   'carat': 0.9,
#   'cut': 'Good',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 63.5,
#   'table': 58.0,
#   'price': 2889,
#   'x': 6.09,
#   'y': 6.14,
#   'z': 3.88},
#  {'index': 949,
#   's': 950,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 62.8,
#   'table': 56.0,
#   'price': 2889,
#   'x': 5.69,
#   'y': 5.72,
#   'z': 3.58},
#  {'index': 950,
#   's': 951,
#   'carat': 0.5,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VVS2',
#   'depth': 62.2,
#   'table': 54.0,
#   'price': 2889,
#   'x': 5.08,
#   'y': 5.12,
#   'z': 3.17},
#  {'index': 951,
#   's': 952,
#   'carat': 0.5,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VVS2',
#   'depth': 62.2,
#   'table': 54.0,
#   'price': 2889,
#   'x': 5.09,
#   'y': 5.11,
#   'z': 3.17},
#  {'index': 952,
#   's': 953,
#   'carat': 0.74,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 61.2,
#   'table': 56.0,
#   'price': 2889,
#   'x': 5.83,
#   'y': 5.87,
#   'z': 3.58},
#  {'index': 953,
#   's': 954,
#   'carat': 0.77,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 61.8,
#   'table': 56.0,
#   'price': 2889,
#   'x': 5.94,
#   'y': 5.9,
#   'z': 3.66},
#  {'index': 954,
#   's': 955,
#   'carat': 0.77,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 59.8,
#   'table': 61.0,
#   'price': 2889,
#   'x': 5.99,
#   'y': 5.95,
#   'z': 3.57},
#  {'index': 955,
#   's': 956,
#   'carat': 0.8,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 61.5,
#   'table': 54.0,
#   'price': 2890,
#   'x': 6.07,
#   'y': 6.0,
#   'z': 3.71},
#  {'index': 956,
#   's': 957,
#   'carat': 0.8,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 62.4,
#   'table': 57.0,
#   'price': 2890,
#   'x': 5.9,
#   'y': 5.87,
#   'z': 3.67},
#  {'index': 957,
#   's': 958,
#   'carat': 0.8,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 61.5,
#   'table': 60.0,
#   'price': 2890,
#   'x': 5.97,
#   'y': 5.94,
#   'z': 3.66},
#  {'index': 958,
#   's': 959,
#   'carat': 0.8,
#   'cut': 'Good',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 63.8,
#   'table': 59.0,
#   'price': 2890,
#   'x': 5.87,
#   'y': 5.83,
#   'z': 3.73},
#  {'index': 959,
#   's': 960,
#   'carat': 0.66,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VVS1',
#   'depth': 61.5,
#   'table': 56.0,
#   'price': 2890,
#   'x': 5.61,
#   'y': 5.58,
#   'z': 3.44},
#  {'index': 960,
#   's': 961,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 61.2,
#   'table': 58.0,
#   'price': 2891,
#   'x': 5.71,
#   'y': 5.79,
#   'z': 3.52},
#  {'index': 961,
#   's': 962,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 61.2,
#   'table': 56.0,
#   'price': 2891,
#   'x': 5.73,
#   'y': 5.77,
#   'z': 3.52},
#  {'index': 962,
#   's': 963,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 61.6,
#   'table': 56.0,
#   'price': 2891,
#   'x': 5.74,
#   'y': 5.76,
#   'z': 3.54},
#  {'index': 963,
#   's': 964,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'VS2',
#   'depth': 62.7,
#   'table': 56.0,
#   'price': 2891,
#   'x': 5.71,
#   'y': 5.75,
#   'z': 3.59},
#  {'index': 964,
#   's': 965,
#   'carat': 0.72,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 61.1,
#   'table': 56.0,
#   'price': 2891,
#   'x': 5.78,
#   'y': 5.81,
#   'z': 3.54},
#  {'index': 965,
#   's': 966,
#   'carat': 0.71,
#   'cut': 'Good',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 62.3,
#   'table': 61.0,
#   'price': 2891,
#   'x': 5.7,
#   'y': 5.73,
#   'z': 3.56},
#  {'index': 966,
#   's': 967,
#   'carat': 0.86,
#   'cut': 'Ideal',
#   'color': 'H',
#   'clarity': 'SI2',
#   'depth': 61.8,
#   'table': 55.0,
#   'price': 2892,
#   'x': 6.12,
#   'y': 6.14,
#   'z': 3.79},
#  {'index': 967,
#   's': 968,
#   'carat': 1.19,
#   'cut': 'Fair',
#   'color': 'H',
#   'clarity': 'I1',
#   'depth': 65.1,
#   'table': 59.0,
#   'price': 2892,
#   'x': 6.62,
#   'y': 6.55,
#   'z': 4.29},
#  {'index': 968,
#   's': 969,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 62.6,
#   'table': 55.0,
#   'price': 2893,
#   'x': 5.66,
#   'y': 5.71,
#   'z': 3.56},
#  {'index': 969,
#   's': 970,
#   'carat': 0.82,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 62.5,
#   'table': 56.0,
#   'price': 2893,
#   'x': 5.99,
#   'y': 6.04,
#   'z': 3.76},
#  {'index': 970,
#   's': 971,
#   'carat': 0.71,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VVS2',
#   'depth': 61.5,
#   'table': 57.0,
#   'price': 2893,
#   'x': 5.73,
#   'y': 5.75,
#   'z': 3.53},
#  {'index': 971,
#   's': 972,
#   'carat': 0.75,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 62.5,
#   'table': 57.0,
#   'price': 2893,
#   'x': 5.78,
#   'y': 5.83,
#   'z': 3.63},
#  {'index': 972,
#   's': 973,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'H',
#   'clarity': 'VVS1',
#   'depth': 59.2,
#   'table': 60.0,
#   'price': 2893,
#   'x': 5.87,
#   'y': 5.78,
#   'z': 3.45},
#  {'index': 973,
#   's': 974,
#   'carat': 0.8,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 62.5,
#   'table': 55.0,
#   'price': 2893,
#   'x': 5.89,
#   'y': 5.92,
#   'z': 3.69},
#  {'index': 974,
#   's': 975,
#   'carat': 0.82,
#   'cut': 'Good',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 59.9,
#   'table': 62.0,
#   'price': 2893,
#   'x': 6.02,
#   'y': 6.04,
#   'z': 3.61},
#  {'index': 975,
#   's': 976,
#   'carat': 0.82,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 63.4,
#   'table': 55.0,
#   'price': 2893,
#   'x': 6.0,
#   'y': 5.93,
#   'z': 3.78},
#  {'index': 976,
#   's': 977,
#   'carat': 0.82,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'SI1',
#   'depth': 59.9,
#   'table': 59.0,
#   'price': 2893,
#   'x': 6.09,
#   'y': 6.06,
#   'z': 3.64},
#  {'index': 977,
#   's': 978,
#   'carat': 0.81,
#   'cut': 'Very Good',
#   'color': 'E',
#   'clarity': 'SI2',
#   'depth': 62.4,
#   'table': 57.0,
#   'price': 2894,
#   'x': 5.91,
#   'y': 5.99,
#   'z': 3.71},
#  {'index': 978,
#   's': 979,
#   'carat': 0.81,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'SI2',
#   'depth': 62.2,
#   'table': 57.0,
#   'price': 2894,
#   'x': 5.96,
#   'y': 6.0,
#   'z': 3.72},
#  {'index': 979,
#   's': 980,
#   'carat': 0.76,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'SI1',
#   'depth': 61.4,
#   'table': 56.0,
#   'price': 2894,
#   'x': 5.88,
#   'y': 5.92,
#   'z': 3.62},
#  {'index': 980,
#   's': 981,
#   'carat': 0.71,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 60.9,
#   'table': 56.0,
#   'price': 2895,
#   'x': 5.75,
#   'y': 5.78,
#   'z': 3.51},
#  {'index': 981,
#   's': 982,
#   'carat': 0.7,
#   'cut': 'Very Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 61.8,
#   'table': 59.0,
#   'price': 2895,
#   'x': 5.66,
#   'y': 5.76,
#   'z': 3.53},
#  {'index': 982,
#   's': 983,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VVS2',
#   'depth': 62.1,
#   'table': 53.0,
#   'price': 2895,
#   'x': 5.71,
#   'y': 5.75,
#   'z': 3.56},
#  {'index': 983,
#   's': 984,
#   'carat': 0.74,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 59.8,
#   'table': 58.0,
#   'price': 2896,
#   'x': 5.85,
#   'y': 5.89,
#   'z': 3.51},
#  {'index': 984,
#   's': 985,
#   'carat': 0.77,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 61.3,
#   'table': 60.0,
#   'price': 2896,
#   'x': 5.81,
#   'y': 5.91,
#   'z': 3.59},
#  {'index': 985,
#   's': 986,
#   'carat': 0.77,
#   'cut': 'Very Good',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 58.3,
#   'table': 63.0,
#   'price': 2896,
#   'x': 6.0,
#   'y': 6.05,
#   'z': 3.51},
#  {'index': 986,
#   's': 987,
#   'carat': 0.53,
#   'cut': 'Ideal',
#   'color': 'F',
#   'clarity': 'VVS1',
#   'depth': 61.6,
#   'table': 56.0,
#   'price': 2896,
#   'x': 5.18,
#   'y': 5.24,
#   'z': 3.21},
#  {'index': 987,
#   's': 988,
#   'carat': 0.79,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI1',
#   'depth': 61.5,
#   'table': 56.0,
#   'price': 2896,
#   'x': 5.91,
#   'y': 5.96,
#   'z': 3.65},
#  {'index': 988,
#   's': 989,
#   'carat': 0.73,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI2',
#   'depth': 61.5,
#   'table': 55.0,
#   'price': 2896,
#   'x': 5.82,
#   'y': 5.86,
#   'z': 3.59},
#  {'index': 989,
#   's': 990,
#   'carat': 0.77,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'SI2',
#   'depth': 62.1,
#   'table': 56.0,
#   'price': 2896,
#   'x': 5.83,
#   'y': 5.89,
#   'z': 3.64},
#  {'index': 990,
#   's': 991,
#   'carat': 0.77,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 60.9,
#   'table': 58.0,
#   'price': 2896,
#   'x': 5.94,
#   'y': 5.88,
#   'z': 3.6},
#  {'index': 991,
#   's': 992,
#   'carat': 1.01,
#   'cut': 'Very Good',
#   'color': 'I',
#   'clarity': 'I1',
#   'depth': 63.1,
#   'table': 57.0,
#   'price': 2896,
#   'x': 6.39,
#   'y': 6.35,
#   'z': 4.02},
#  {'index': 992,
#   's': 993,
#   'carat': 1.01,
#   'cut': 'Ideal',
#   'color': 'I',
#   'clarity': 'I1',
#   'depth': 61.5,
#   'table': 57.0,
#   'price': 2896,
#   'x': 6.46,
#   'y': 6.45,
#   'z': 3.97},
#  {'index': 993,
#   's': 994,
#   'carat': 0.6,
#   'cut': 'Very Good',
#   'color': 'D',
#   'clarity': 'VVS2',
#   'depth': 60.6,
#   'table': 57.0,
#   'price': 2897,
#   'x': 5.48,
#   'y': 5.51,
#   'z': 3.33},
#  {'index': 994,
#   's': 995,
#   'carat': 0.76,
#   'cut': 'Premium',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 61.1,
#   'table': 58.0,
#   'price': 2897,
#   'x': 5.91,
#   'y': 5.85,
#   'z': 3.59},
#  {'index': 995,
#   's': 996,
#   'carat': 0.54,
#   'cut': 'Ideal',
#   'color': 'D',
#   'clarity': 'VVS2',
#   'depth': 61.4,
#   'table': 52.0,
#   'price': 2897,
#   'x': 5.3,
#   'y': 5.34,
#   'z': 3.26},
#  {'index': 996,
#   's': 997,
#   'carat': 0.72,
#   'cut': 'Ideal',
#   'color': 'E',
#   'clarity': 'SI1',
#   'depth': 62.5,
#   'table': 55.0,
#   'price': 2897,
#   'x': 5.69,
#   'y': 5.74,
#   'z': 3.57},
#  {'index': 997,
#   's': 998,
#   'carat': 0.72,
#   'cut': 'Good',
#   'color': 'F',
#   'clarity': 'VS1',
#   'depth': 59.4,
#   'table': 61.0,
#   'price': 2897,
#   'x': 5.82,
#   'y': 5.89,
#   'z': 3.48},
#  {'index': 998,
#   's': 999,
#   'carat': 0.74,
#   'cut': 'Premium',
#   'color': 'D',
#   'clarity': 'VS2',
#   'depth': 61.8,
#   'table': 58.0,
#   'price': 2897,
#   'x': 5.81,
#   'y': 5.77,
#   'z': 3.58},
#  {'index': 999,
#   's': 1000,
#   'carat': 1.12,
#   'cut': 'Premium',
#   'color': 'J',
#   'clarity': 'SI2',
#   'depth': 60.6,
#   'table': 59.0,
#   'price': 2898,
#   'x': 6.68,
#   'y': 6.61,
#   'z': 4.03},
#  ...]

# %%
coll.insert_many(data)

# %%
coll.count_documents({})
# Out:
# 53940

# %%
client.close()
